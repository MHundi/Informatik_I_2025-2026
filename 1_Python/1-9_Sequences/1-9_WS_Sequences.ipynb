# %% [raw]
# ---
# format:
#   pdf:
#     pdf-engine: xelatex
#     documentclass: scrartcl
#     papersize: a4
#     fontsize: 11pt
#     geometry: top=3cm, bottom=2cm, left=4cm, right=2cm
#     fig-align: center
#     colorlinks: true
#     code-line-numbers: true
#     keep-tex: true
#     include-in-header:
#       - text: |
#           \usepackage[document]{ragged2e}
#
#   beamer:
#     aspectratio: 169
#     navigation: horizontal
#     theme: Singapore
#     colortheme: orchid
#     toc: false
#     code-line-numbers: true
#     echo: false
#     fontsize: 25pt
#
#   html:
#     standalone: true
#     section-divs: true
#     html-math-method: mathjax
#     wrap: none
#     default-image-extension: png
#
# mainfont: Avenir Next
# ---

# %% [markdown]
# ## Arbeitsblatt – Tupel und Listen in Python

# %% [markdown]
# ### Aufgabe 1
#
# Gegeben ist folgendes Tupel:
#
# ```python
# primes = (2, 3, 5, 7, 11, 13)
# ```
#
# 1. Gib das **zweite Element** des Tupels aus.
# 2. Gib das **letzte Element** aus (nutze einen negativen Index).
# 3. Gib die **Länge des Tupels** aus.

# %%
# Lösung zu Aufgabe 1

# %% [markdown]
# ### Aufgabe 2
#
# Erstelle eine Liste:
#
# ```python
# numbers = [4, 8, 15, 16, 23, 42]
# ```
#
# 1. Gib das **erste** und das **letzte Element** aus.
# 2. Berechne die **Summe der Liste**.
# 3. Gib das **Minimum** und das **Maximum** der Liste aus.

# %%
# Lösung zu Aufgabe 2

# %% [markdown]
# ### Aufgabe 3
#
# Gegeben:
#
# ```python
# a = [1, 2, 3]
# b = [4, 5]
# ```
#
# 1. Verbinde beide Listen zu einer neuen Liste.
# 2. Wiederhole die Liste `a` **dreimal**.
# 3. Verbinde das Tupel `(7, 8)` mit sich selbst.

# %%
# Lösung zu Aufgabe 3

# %% [markdown]
# ### Aufgabe 4
#
# Gegeben:
#
# ```python
# food = ("Pizza", "Salat", "Burger", "Pasta")
# ```
#
# 1. Prüfe, ob `"Pizza"` im Tupel enthalten ist.
# 2. Prüfe, ob `"Sushi"` enthalten ist.
# 3. Gib eine passende Meldung aus, wenn `"Salat"` vorkommt.
#
# Nutze dafür den **`in`-Operator**.

# %%
# Lösung zu Aufgabe 4

# %% [markdown]
# ### Aufgabe 5
#
# Gegeben ist das Tupel:
#
# ```python
# numbers = (10, 20, 30, 40, 50, 60, 70)
# ```
#
# 1. Gib die **ersten drei Elemente** aus.
# 2. Gib die **letzten zwei Elemente** aus.
# 3. Gib eine **Kopie des gesamten Tupels** mithilfe von Slicing aus.

# %%
# Lösung zu Aufgabe 5

# %% [markdown]
# ### Aufgabe 6
#
# Gegeben:
#
# ```python
# point = (4, 7)
# ```
#
# 1. Weise die Werte des Tupels den Variablen `x` und `y` zu.
# 2. Gib beide Werte aus.
#
# Erweiterung:
#
# ```python
# data = (42, (6, 9), "do")
# ```
#
# Entpacke das Tupel so, dass du auf die einzelnen Werte zugreifen kannst.

# %%
# Lösung zu Aufgabe 6

# %% [markdown]
# ### Aufgabe 7
#
# Gegeben:
#
# ```python
# t = (3, 6, 9)
# ```
#
# 1. Wandle das Tupel in eine **Liste** um.
# 2. Füge der Liste die Zahl **12** hinzu.
# 3. Wandle die Liste anschließend wieder in ein **Tupel** um.
#
# Nutze dafür `list()` und `tuple()`.

# %%
# Lösung zu Aufgabe 7

# %% [markdown]
# ### Aufgabe 8
#
# Gegeben ist die Liste:
#
# ```python
# values = [12, 5, 8, 21, 3, 17]
# ```
#
# 1. Erzeuge eine **sortierte Version der Liste**.
# 2. Prüfe mit `any()`, ob eine Zahl **größer als 20** ist.
# 3. Prüfe mit `all()`, ob **alle Zahlen positiv** sind.

# %%
# Lösung zu Aufgabe 8

# %% [markdown]
# ### Zusatzaufgabe
#
# Gegeben:
#
# ```python
# letters = ["p", "y", "t", "h", "o", "n"]
# ```
#
# 1. Verbinde die Liste zu einem String mit `"".join()`.
# 2. Verbinde die Buchstaben mit `"-"`.
#
# Beispiel:
#
# ```python
# p-y-t-h-o-n
# ```

# %%
# Lösung zur Zusatzaufgabe
